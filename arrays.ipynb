# %%
a=10
b=30
a,b=b,a
print(a,b)
# Out:
# 30 10

# %%
print("hello")
# Out:
# hello

# %%
class solution:
    def pushzerostoend(arr):
        j=len(arr)-1
        i=0
        # while  i<j:
        for i in range(len(arr)):
            # if arr[j]==0 and arr[j]!=0:
            #     arr[i],arr[j]=arr[j],arr[i]
            #     i+=1
            #     j+=1
            if arr[i]!=0:
                arr[i],arr[j]=arr[j],arr[i]
                j+=1

# %%
# class solution:
arr=[5,1,0,2,6]
    # def pushzerostoend(self,arr):
j=len(arr)-1
i=0
while  i<j:
# for i in range(len(arr)):
            if arr[i]!=0:
                i+=1
            elif arr[j]!=0 & arr[i]==0:
                arr[i],arr[j]=arr[j],arr[i]
                i+=1
                j-=1
print(arr)
# Out:
# [5, 1, 6, 2, 0]

# %%
j=0
arr=[5,1,0,2,6]
for i in range(len(arr)):
    if arr[i]!=0:
        arr[i],arr[j]=arr[j],arr[i]
        j+=1
        # arr=[5,1,0,2,6]
print(arr)
# Out:
# [5, 1, 2, 6, 0]

# %%
#code to remove duplicates
a=[1,1,2,2,3,3,4,5,6,4,6,5]
a=[1,1,2,2,3,3]
j=0
for i in range(len(a)):
    if a[i]!=a[j]:
        j+=1
        a[j]=a[i]
print(a)
# a=[1,1,2,2,3,3,4,5,6,4,6,5]
print(j)
print(a)
print(a[:j+1])
# Out:
# [1, 2, 3, 2, 3, 3]
# 2
# [1, 1, 2, 2, 3, 3, 4, 5, 6, 4, 6, 5]
# [1, 1, 2]

# %%
# code to remove duplicates
a = [1, 1, 2, 2, 3, 3, 4, 5, 6, 4, 6, 5]

a.sort()
j = 0

for i in range(1, len(a)):
    if a[i] != a[j]:
        j += 1
        a[j] = a[i]

print(a[:j + 1])
print(j + 1)
# Out:
# [1, 2, 3, 4, 5, 6]
# 6

# %%
a = [1, 1, 2, 2, 3, 3, 4, 5, 6, 4, 6, 5]

unique = []

for item in a:
    if item not in unique:
        unique.append(item)

print(unique)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1, 1, 2, 2, 3, 3, 4, 5, 6, 4, 6, 5]

a = list(dict.fromkeys(a))

print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#next permutation / combnation
a=[1,2,3,4,5]
# i=a(len)-2  #intializing i
for i,j in a:
  i=(len)-2
  if i>0 and a[i]>=a[i+1]:
        j=a(len)-1
        a[j]<=a[i]
        a[i]=a[j]
        i+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 #next permutation / combnation
#       2 a=[1,2,3,4,5]
#       3 # i=a(len)-2  #intializing i
#       4 # for i,j in a:
# ----> 5 i=(len)-2
#       6 if i>0 and a[i]>=a[i+1]:
#       7         j=a(len)-1
#       8         a[j]<=a[i]
#
# TypeError: unsupported operand type(s) for -: 'builtin_function_or_method' and 'int'

# %%
a=[2,4,1,5,7,0]
i=len(a)-2
while i>=0 and a[i]>=a[i+1]:
    i-=1
if i>=0:
    j=len(a)-1
    # while a[j]<=a[i]:
    while a[j]<=a[i]:
        j=-1
    a[i],a[j]=a[j],a[i]
i+=1
j=len(a)-1
while i<j:
    a[i],a[j]=a[j],a[i]
    i+=1
    j-=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       4     i-=1
#       5 if i>=0:
#       6     j=len(a)-1
#       7     # while a[j]<=a[i]:
# ----> 8     while a[j]<=a[i]:
#       9         j=-1
#      10     a[i],a[j]=a[j],a[i]
#      11 i+=1
#
# KeyboardInterrupt:

# %%
a = [2, 4, 1, 5, 7, 0]
i = len(a) - 2
while i >= 0 and a[i] >= a[i + 1]:
    i -= 1
if i >= 0:
        j=len(a)-1
        while a[j]<=a[i]:
           j -= 1
           a[i], a[j] = a[j], a[i]
i += 1
j = len(a) - 1
while i < j:
    a[i], a[j] = a[j], a[i]
    i += 1
    j -= 1
print(a)
# Out:
# [2, 4, 7, 1, 0, 5]

# %%
A=[1,2,3,2,4,2,5,5,1,6,6,7]
# def findmajority(self,a):
d={}
a=[]
for i in A:
     d[i]=d.get(i,0)+1        
for i in d:
    if d[i]>len(a)/3:
       print( i)
    a.append(i)   
print(a)
# findmajority(self,[1,2,3,2,4,2,5,5,1,6])
# Out:
# 1
# 2
# 3
# 5
# 6
# [1, 2, 3, 4, 5, 6, 7]

# %%
#remove duplicates
a="aaaabccc"
d={}
for i in a:
    d[i]=d.get(i,0)+1
print(d)
s=""
for i in d:
#    if d[i]==1:
      s=s+i
print(s)
# Out:
# {'a': 4, 'b': 1, 'c': 3}
# abc

# %%
#stock buy and sell
#mulitiple transactions
a=[5,7,9,13,15,21,67,100]
profit=[]
for i in range(1,len(a)):
    if a[i]>a[i-1]:
      #profit.append(a)
      profit.append(a[i]-a[i-1])
print(profit)
# Out:
# [2, 2, 4, 2, 6, 46, 33]

# %%
#stock buy and sell
#max one transaction allowed
a=[5,7,9,110,100,120]
minprice=a[0]
maxprofit=0
for i in range(1,len(a)):
    minprice=min(minprice,a[i])
    maxprofit=max(maxprofit,a[i]-minprice)
print(maxprofit)
# Out:
# 115

# %%
arr = [10, 20, 30, 89, 99, 111]
d = 3 # number of positions to rotate left
d %= len(arr)
arr[:] = arr[d:] + arr[:d]
print(arr)
#positions to move to the left
# Out:
# [89, 99, 111, 10, 20, 30]

# %%
# next permutation
def nextper(a):
    i = len(a) - 2
    while i >= 0 and a[i] >= a[i + 1]:
        i -= 1

    if i >= 0:
        j = len(a) - 1
        while a[j] <= a[i]:
            j -= 1
        a[i], a[j] = a[j], a[i]

    a[i + 1:] = reversed(a[i + 1:])
    return a

print(nextper([10, 60, 70, 40, 50, 90]))
# Out:
# [10, 60, 70, 40, 90, 50]

# %%
def maxprofit(prices):
    minprice = prices[0]
    maxprofit = 0

    for i in range(1, len(prices)):
        minprice = min(minprice, prices[i])
        maxprofit = max(maxprofit, prices[i] - minprice)

    return maxprofit


print(maxprofit([23, 45, 67, 78, 90]))
# Out:
# 67

# %%
def maxprofit(prices):
    minprice=prices[0]
    maxprofit=0
    for i in range(1,len(prices)):
        minprice=min(minprice,prices[i])
        maxprofit=max(maxprofit,prices[i]-minprice)
        print(maxprofit)
    return maxprofit
print(maxprofit([23,45,67,78,90]))
#for stock buy and sell ax one transaction allowed
# Out:
# 22
# 44
# 55
# 67
# 67

# %%
def maxprofit(prices):
    profit=0
    for i in range(1,len(prices)):
        if prices[i]>prices[i-1]:
            profit+=prices[i]-prices[i-1]
        print(profit)
    return profit
print(maxprofit([100,180,260,310,40,535,695]))
#for stock buy and sell multiple transactions allowed
#need to look at copoiliot tommorow for breif explanation
# Out:
# 80
# 160
# 210
# 210
# 705
# 865
# 865

# %%
def findmajority(arr):
    d={}
    for i in arr:
        d[i]=d.get(i,0)+1
    a=[]
    for i in d:
        if d[i]>len(arr)//3:
            a.append(i)
    a.sort()
    return a
print(findmajority([34,56,76,76,89,76,76,99,99,99]))
#finds majority(majourly repeated) element
# Out:
# [76]

# %%
a=[2,3,-8,7,-1,2,3]
#kandane"s alorgithm
current= big= a[0]
for i in range(1,len(a)):
    current=max(a[i],current+a[i])
    big=max(big,current)
print(big)
# Out:
# 11

# %%
a=[2,3,-8,7,-1,2,3]
#kandane"s alorgithm
current= big= a[0]
for i in range(1,len(a)):
    # if current+a[i]<a[i]:
    #     a.clear()
    current=max(a[i],current+a[i])
    big=max(big,current)
print(big)
# Out:
# 11

# %%
a = [2, 3, -8, 7, -1, 2, 3]
# Kadane's algorithm: find the maximum sum of a contiguous subarray

current_sum = a[0]
maximum_sum = a[0]
start = 0
best_start = 0
best_end = 0

for i in range(1, len(a)):
    if a[i] > current_sum + a[i]:
        current_sum = a[i]
        start = i
    else:
        current_sum += a[i]

    if current_sum > maximum_sum:
        maximum_sum = current_sum
        best_start = start
        best_end = i
    print(maximum_sum)

print("Maximum sum:", maximum_sum)
print("Subarray:", a[best_start:best_end + 1])
# Out:
# 5
# 5
# 7
# 7
# 8
# 11
# Maximum sum: 11
# Subarray: [7, -1, 2, 3]

# %%
# Maximum product subarray

def max_product_subarray(arr):
    if not arr:
        raise ValueError("The array must not be empty")

    current_max = arr[0]
    current_min = arr[0]
    maximum_product = arr[0]

    for number in arr[1:]:
        candidates = (number, current_max * number, current_min * number)
        current_max = max(candidates)
        current_min = min(candidates)
        maximum_product = max(maximum_product, current_max)
        print(maximum_product)

    return maximum_product
       


arr = [-2, 6, -3, -10, 0, 2]
print("Maximum product:", max_product_subarray(arr))
# Out:
# 6
# 36
# 180
# 180
# 180
# Maximum product: 180

# %%
# Maximum product subarray
arr = [-2, 6, -3, -10, 0, 2]
minpro=maxpro=ans=arr[0]
for i in range(1,len(arr)):
    x=arr[i]
    if x<0:
        minpro,maxpro=maxpro,minpro
    maxpro=max(x,maxpro*x)
    minpro=min(x,minpro*x)
    big=max(big,maxpro)
#print(big)
print(big)
#piont first 6 and choose 6 or -2 which is big and 
#go for multiplication and go on
'''big---6 -18 -60 180
   small-- -2 -if product is big swap   and loop ends on 0 condition fail'''
# Out:
# 180
# 'big---6 -18 -60 180\n   small-- -2 -if product is big swap   and loop ends on 0 condition fail'

# %%
arr = [8, -8, 9, -9, 10, -11, 18]


def kadane(numbers):
    current = best = numbers[0]

    for number in numbers[1:]:
        current = max(number, current + number)
        best = max(best, current)

    return best


def circular_max_subarray(numbers):
    maximum_sum = kadane(numbers)

    # If every number is negative, the non-circular result is correct.
    if maximum_sum < 0:
        return maximum_sum

    total = sum(numbers)
    minimum_sum = -kadane([-number for number in numbers])
    return max(maximum_sum, total - minimum_sum)


def circular_min_subarray(numbers):
    minimum_sum = -kadane([-number for number in numbers])

    # If every number is positive, the non-circular result is correct.
    if minimum_sum > 0:
        return minimum_sum

    total = sum(numbers)
    maximum_sum = kadane(numbers)
    return min(minimum_sum, total - maximum_sum)


print("Maximum circular subarray sum:", circular_max_subarray(arr))
print("Minimum circular subarray sum:", circular_min_subarray(arr))
# Out:
# Maximum circular subarray sum: 28
# Minimum circular subarray sum: -11

# %%
arr = [8, -8, 9, -9, 10, -11, 18]
#maximum sum
cur_max = big = arr[0]
cur_min = small = arr[0]
for i in range(1, len(arr)):
    cur_max = max(arr[i], cur_max + arr[i])
    big = max(big, cur_max)
    cur_min = min(arr[i], cur_min + arr[i])
    small = min(small, cur_min)
print(big)
print(small)
# Out:
# 18
# -11

# %%
# arr = [8, -8, 9, -9, 10, -11, 18]
# #maxium sum 
# #minium sum in circular array
# total=sum(arr)
# cur_max=arr[0]
# big=arr[0]
# small=arr[0]
# for i in range(1,len(arr)):
#     cur_max=max(arr[i],cur_max+arr[i])
#     big=max(big,cur_max)
#     cur_min=min(arr[i],cur_min+arr[i])
#     small=(small,cur_min)
# if cur_max<0:
#     print(cur_max)
# cir_max==total-cur_min
# print(max(cir_max,cur_max))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 arr = [8, -8, 9, -9, 10, -11, 18]
#       2 #maxium sum
#       3 #minium sum in circular array
#       4 total=sum(arr)
# ----> 5 cur_max,big,small,cur_min=arr[0]
#       6 for i in range(1,len(arr)):
#       7     cur_max=max(arr[i],cur_max+arr[i])
#       8     big=max(big,cur_max)
#
# TypeError: cannot unpack non-iterable int object

# %%
arr = [8, -8, 9, -9, 10, -11, 12]
#maxium sum 
#minium sum in circular array
total=sum(arr)
cur_max = big = arr[0]
cur_min = small = arr[0]

for i in range(1,len(arr)):
    cur_max=max(arr[i],cur_max+arr[i])
    big=max(big,cur_max)
    cur_min=min(arr[i],cur_min+arr[i])
    small=min(small,cur_min)
if big<0:
    print(big)
cir_max=total-small
print(max(cir_max,small))
print(max(cir_max,big))
#date(26-08-26)
# Out:
# 22
# 22

# %%
arr = [8, -8, 9, -9, 10, -11, 12]
#maximum sum
#minimum sum in circular array
total = sum(arr)
cur_max = big = arr[0]
cur_min = small = arr[0]
for i in range(1, len(arr)):
    cur_max = max(arr[i], cur_max + arr[i])
    big = max(big, cur_max)
    cur_min = min(arr[i], cur_min + arr[i])
    small = min(small, cur_min)

circular_max = total - small if big > 0 else big
print(max(big, circular_max))
# Out:
# 22

# %%
#smallest positive missing
arr=[2,-3,4,1,1,7]
a=set(arr)
i=1
while i in a:
    i+=1
print(i)
# Out:
# 3

# %%
#smallest positive missing
arr=[2,-3,4,1,1,7]
# a=set(arr)
i=1
while i in arr:
    i+=1
print(i)
# Out:
# 3
