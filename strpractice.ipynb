# %%
str="nishazareentaj"
print(str)
target="j"
def strfind():
    # target="j"
    for i in str:
        if i=="j":
          print(i)
            # print(i)
    # str.split()
    # for i in range(str):
    #     if i=="j":
    #         print(i)

strfind()
# Out:
# nishazareentaj
# j

# %%
def find():
    str="nisha"
    target="a"
    for i in str:
        if i==target:
            print(i)
find()
# Out:
# a

# %%
def reverse_string(s):
    rev = ""
    for char in s:
        rev = char + rev # add char to front
    return rev

text = input("Enter string: ")
print("Reversed:", reverse_string(text))

# %%
def reverse():
    str="nisha"
    reversed_str=" "
    for i in str:
        reversed_str=i+reversed_str
    print(f"reversed string is {reversed_str}")
reverse()

# %%
def reverse_string(s):
    return "".join(reversed(s))

text = input("Enter string: ")
print("Reversed:", reverse_string(text))

# %%
def is_palindrome(s):
    s = s.lower().replace(" ", "") # ignore case and spaces
    return s == s[::-1]

text = input("Enter string: ")
if is_palindrome(text):
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
def is_palindrome(s):
    s = s.lower().replace(" ", "") # clean the string
    left, right = 0, len(s) - 1

    while left < right:
        if s[left]!= s[right]:
            return False
        left += 1
        right -= 1
    return True

text = input("Enter string: ")
print("Palindrome" if is_palindrome(text) else "Not Palindrome")

# %%
def find_index(text, target):
    for index, char in enumerate(text):
        if char == target:
            return index # returns first match
    return -1 # if not found

s = "nishazareentaj"
target = 'j'
result = find_index(s, target)
print(f"First '{target}' found at index: {result}")

# %%
def findindex():
    str="olkar"
    target="k"
    for i,j  in enumerate(str):
        if j==target:
            return i
findindex()
# Out:
# 2

# %%
def fidind():
    str="nisha"
    target="a"
    for i,j in enumerate(str):
        if j==target:
            print(i)
fidind()
# Out:
# 4

# %%
def findindex():
    for i ,j in enumerate(str):
        if j==target:
            return  i
    return -1
str="olkar"
target="k"
result=findindex()
print(target,result)
# Out:
# k 2

# %%
def find_all_indexes(text, target):
    indexes = []
    for i in range(len(text)):
        if text[i] == target:
            indexes.append(i)
    return indexes

s = "zareentaj"
target = 'a'
result = find_all_indexes(s, target)
print(f"All indexes of '{target}': {result}")
# Out:
# All indexes of 'a': [1, 7]

# %%
def findallindex(text,target):
    emptylist=[]
    for i in range(len(text)):
        if text[i]==target:
            emptylist.append(i)
    return emptylist
str="nishazareentaj jaganmohanreddy"
target="a"
result=findallindex(str,target)
print(f"all indexes of {target} is : {result}")
# Out:
# all indexes of a is : [4, 6, 12, 16, 18, 23]

# %%
def allindex(text,target):
    emptylist=[]
    for i in range(len(text)):
        if text[i]==target:
            emptylist.append(i)
    print(emptylist)
string="nishazareentajkolkar"
target="a"
result=allindex(string,target)
print(f"all indexes of target {target}")
# Out:
# [4, 6, 12, 18]
# all indexes of target a

# %%
def find_substring(text, sub):
    n = len(text)
    m = len(sub)
    for i in range(n - m + 1):
        if text[i : i + m] == sub: # check slice
            return i
    return -1

s = "python programming"
sub = "gram"
print(f"'{sub}' found at index:", find_substring(s, sub))
# Out:
# 'gram' found at index: 10

# %%
string = "nishataj"
substring = "taj"

start_index = string.find(substring)

if start_index != -1:
    end_index = start_index + len(substring) - 1
    print(f"Substring found at index {start_index}-{end_index}")
else:
    print("Substring not found")
# Out:
# Substring found at index 5-7

# %%
def find_substring(string, substring):
    index = string.find(substring)

    if index == -1:
        return "Substring not found"

    return f"Substring found at index {index}-{index + len(substring) - 1}"


print(find_substring("nishataj", "taj"))
# Out:
# Substring found at index 5-7

# %%
def substring(str,sub):
    i=str.find(sub)
    if i==-1:
        return "substring not found"
    return f'substring found at index{i}-{i+len(sub)-1}'
print(substring("nisha","ha"))
# Out:
# substring found at index3-4

# %%
def find_substring(string, substring):
    for index in range(len(string) - len(substring) + 1):
        if string[index:index + len(substring)] == substring:
            end_index = index + len(substring) - 1
            return f"Substring found at index {index}-{end_index}"

    return "Substring not found"


print(find_substring("nishataj", "taj"))
# Out:
# Substring found at index 5-7

# %%
def find_substring(string, substring):
    result = {}-

    for index in range(len(string) - len(substring) + 1):
        if string[index:index + len(substring)] == substring:

            for position in range(len(substring)):
                result[substring[position]] = index + position

            return result

    return "Substring not found"


answer = find_substring("nishataj", "taj")
print(answer)
# Out:
# {'t': 5, 'a': 6, 'j': 7}

# %%
def findsub(text,sub):
    n=len(text)
    m=len(sub)
    for i in range(n-m+1):
        if text[i:i+m]==sub:
            return i
    return -1
str="nishataj"
sub='taj'
print(f"your substring {sub}found at index" ,findsub(str,sub))
# Out:
# your substring tajfound at index 5

# %%
def findsubstring(text,sub):
    m=len(text)
    n=len(sub)
    for i in range(m-n+1):
        if text[i:m]==sub:
            return i
    return -1
str="nishataj"
sub="taj"
print(f"your substring {sub} found at :",findsubstring(str,sub))
# Out:
# your substring taj found at : 5

# %%
def fu():
    str="jaganzareentaj"
    target="n"
    for i in str:
       if i==target:
        print(f"target letter '{target}' found , {i}")
        #break
fu()
def func():
    str="nishazareentaj"
    target="z"
    for i,j in enumerate(str):
        if j==target:
           print(f"found target '{target}' at index {i} ")
func()
def reverse():
   str="nisha"
   reversed="  " 
   for i in str:
      reversed=i+reversed
   print(f"reversed string is {reversed}")
reverse()
# str="nisha"
# join(reversed(str))
# print(str)
def amd():
   return "".join(reversed(str))
str="nisha"
# print(reversed(str))
amd()

# %%
# select version();
# show tables;
# create table crew(
#            name varchar(20),
#            email varchar(50),
#            rollno int,
#            phonenumber bigint,
#            gender char(1),
#            pincode char(6)
#            ); 
# select * from crew;
# -- we cannot edit columns onece saved we have to alter it using alter command
# -- drop table crew;  after running this we can run the code agaain to add columns
# describe crew;
# desc crew; 
# explain crew;
# -- both are same

# %%
str="kolkarnishazareentaj"
print(len(str))
def find():
    for i in str:
        if i=="z":
            print(i)
find()
str="zareentaj"
target='z'
def index():
    for i,j in enumerate(str):
        if i==target:
            print(i)
index()
# Out:
# 20
# z

# %%
string="algonex"
target="x"
def index():
    for i,j in enumerate(string):
        if j==target:
            print(i)
index()
# Out:
# 6

# %%
empty=[]
def allindex(text,target):
    # empty=[]
    for i,j in enumerate(text):
        if j==target:
            empty.append(i)
    print(empty)
str='nishajaganzareentaj'
target="a"
result=allindex(str,target)
print(f"all indexes to the target {target}  is {empty}")
# Out:
# [4, 6, 8, 11, 17]
# all indexes to the target a  is [4, 6, 8, 11, 17]
